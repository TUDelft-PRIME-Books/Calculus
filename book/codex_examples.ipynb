# %% [markdown]
# # Code example
#
# {ref}`example:code` shows how to run code in a gated code example.
#
# :::{codex-start}
# :label: example:code
#
# Run the next piece of code
#
# :::

# %%
print("Hello from a code cell in Sphinx Book!")

# %% [markdown]
# which should be a piece of cake
#
# :::{codex-end}
# :::
